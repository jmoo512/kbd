# %%
import psycopg2
import pandas as pd

# %%
conn = psycopg2.connect(host="ec2-184-73-210-189.compute-1.amazonaws.com", port = 5432, database="d2pmjsmj1pat21", user="aobhdjhqnrrcrb", password="cea328c1695a2b2cccaf0d79fa8312356185029ab8d391e56ba2e1d18b87b6c2")

# %%
def create_pandas_table(sql_query, database = conn):
    table = pd.read_sql_query(sql_query, database)
    return table

# %%
cur = conn.cursor()
vendor_info = create_pandas_table("SELECT * FROM sales")
cur.close()
conn.close()
df=vendor_info

# %%
df
# Out:
#         id week_ending fiscal_month  fiscal_year  week_of_month  week_of_year  \
# 0        3  2020-03-15        March         2020              3            11
# 1        4  2020-03-15        March         2020              3            11
# 2        5  2020-03-15        March         2020              3            11
# 3        6  2020-03-15        March         2020              3            11
# 4        7  2020-03-15        March         2020              3            11
# ...    ...         ...          ...          ...            ...           ...
# 1562  2998  2020-03-08        March         2020              2            10
# 1563  2999  2020-03-08        March         2020              2            10
# 1564  3000  2020-03-08        March         2020              2            10
# 1565  3001  2020-03-08        March         2020              2            10
# 1566  3002  2020-03-08        March         2020              2            10
#
# ...

# %%
df.drop(columns=['id','fiscal_month','fiscal_year','week_of_month','week_of_year','concept','bbq_sales','taco_sales','group_meal_sales','mavn_sales','doordash_sales','total_guest_count','bbq_guest_count','taco_guest_count'],inplace=True)

# %%
df.sort_values(by='week_ending')
# Out:
#    week_ending    location     sales
# 15  2017-01-08        MFT1    2830.0
# 16  2017-01-08        MFT2   15458.0
# 19  2017-01-08  Round Rock  165039.0
# 14  2017-01-08         MF4   52862.0
# 13  2017-01-08         MF3   48782.0
# ..         ...         ...       ...
# 3   2020-03-15         MF1   48449.0
# 2   2020-03-15       Lamar  101523.0
# 1   2020-03-15         620  109862.0
# 0   2020-03-15  Round Rock  204077.0
# 10  2020-03-22         183  126059.0
#
# [1567 rows x 3 columns]

# %%
north=df[df['location'] == '183']
df=df[df['location']=='183']

# %%
df
# Out:
#      week_ending location     sales
# 8     2020-03-15      183  178039.0
# 10    2020-03-22      183  126059.0
# 21    2017-01-08      183  178988.0
# 32    2017-01-15      183  220394.0
# 43    2017-01-22      183  221491.0
# ...          ...      ...       ...
# 1526  2020-02-09      183  189063.0
# 1536  2020-02-16      183  206188.0
# 1546  2020-02-23      183  208037.0
# 1556  2020-03-01      183  214975.0
# 1566  2020-03-08      183  209525.0
#
# [150 rows x 3 columns]

# %%
north['week_ending']=north['week_ending'].astype('datetime64[ns]')
north.sort_values(by='week_ending', inplace=True)
north.reset_index(inplace=True)
north.drop(columns='index')
# Out:
# <ipython-input-329-8b15945bb4d4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   north['week_ending']=north['week_ending'].astype('datetime64[ns]')
# <ipython-input-329-8b15945bb4d4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   north.sort_values(by='week_ending', inplace=True)
#     week_ending location     sales
# 0    2017-01-08      183  178988.0
# 1    2017-01-15      183  220394.0
# 2    2017-01-22      183  221491.0
# 3    2017-01-29      183  212698.0
# 4    2017-02-05      183  222036.0
# ..          ...      ...       ...
# ...
