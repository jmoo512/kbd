# %%
import pandas as pd
from psql_config import config
import psycopg2

params=config()
conn=psycopg2.connect(**params)
def create_pandas_table(sql_query, database = conn):
    table = pd.read_sql_query(sql_query, database)
    return table

cur = conn.cursor()
bag_times_data = create_pandas_table("SELECT fiscal_year, fiscal_month, week_of_month, week_of_year, quarter, week_avg, month_avg, quarter_avg FROM bagtimes WHERE location='MF4' AND quarter=(SELECT MAX(quarter) FROM bagtimes) OR quarter=(SELECT MAX(quarter)-1 FROM bagtimes) ORDER BY fiscal_year, quarter, fiscal_month, week_of_month")
cur.close()
conn.close()

df=bag_times_data

# %%
df
# Out:
#    fiscal_year fiscal_month  week_of_month  week_of_year  quarter  week_avg  \
# 0         2020            6              1            23        2       313
# 1         2020            6              2            24        2       314
# 2         2020            6              3            25        2       319
#
#    month_avg  quarter_avg
# 0        NaN          NaN
# 1        NaN          NaN
# 2      315.0        315.0
