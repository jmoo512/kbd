# %%
import pandas as pd
from psql_config import config
import psycopg2

params=config()
conn=psycopg2.connect(**params)
def create_pandas_table(sql_query, database = conn):
    table = pd.read_sql_query(sql_query, database)
    return table

cur = conn.cursor()
taco_data = create_pandas_table("SELECT fiscal_year, fiscal_month, week_of_month, week_of_year, quarter, time_in_seconds FROM tacotimes WHERE concept='Rudys' AND quarter=(SELECT MAX(quarter) FROM tacotimes) OR quarter=(SELECT MAX(quarter)-1 FROM tacotimes) ORDER BY fiscal_year, quarter, fiscal_month, week_of_month")
cur.close()
conn.close()

df=taco_data

# %%
df
# Out:
#     fiscal_year fiscal_month  week_of_month  week_of_year  quarter  \
# 0          2020            5              4            21        2
# 1          2020            5              4            21        2
# 2          2020            5              4            21        2
# 3          2020            5              4            21        2
# 4          2020            5              4            21        2
# 5          2020            5              4            21        2
# 6          2020            5              4            21        2
# 7          2020            5              4            21        2
# 8          2020            5              4            21        2
# 9          2020            5              4            21        2
# 10         2020            5              4            21        2
# 11         2020            5              4            21        2
# 12         2020            5              4            21        2
# 13         2020            5              4            21        2
# 14         2020            5              5            22        2
# 15         2020            5              5            22        2
# 16         2020            5              5            22        2
# 17         2020            5              5            22        2
# 18         2020            5              5            22        2
# 19         2020            5              5            22        2
# 20         2020            5              5            22        2
# 21         2020            5              5            22        2
# 22         2020            5              5            22        2
# 23         2020            5              5            22        2
# 24         2020            5              5            22        2
# 25         2020            5              5            22        2
# 26         2020            5              5            22        2
# 27         2020            5              5            22        2
# 28         2020            6              1            23        2
# 29         2020            6              1            23        2
# 30         2020            6              1            23        2
# 31         2020            6              1            23        2
# 32         2020            6              1            23        2
# 33         2020            6              1            23        2
# 34         2020            6              1            23        2
# 35         2020            6              1            23        2
# 36         2020            6              1            23        2
# 37         2020            6              1            23        2
# 38         2020            6              1            23        2
# 39         2020            6              1            23        2
# 40         2020            6              1            23        2
# 41         2020            6              1            23        2
# 42         2020            6              2            24        2
# 43         2020            6              2            24        2
# 44         2020            6              2            24        2
# 45         2020            6              2            24        2
# 46         2020            6              2            24        2
# 47         2020            6              2            24        2
# 48         2020            6              2            24        2
# 49         2020            6              2            24        2
# 50         2020            6              2            24        2
# 51         2020            6              2            24        2
# 52         2020            6              2            24        2
# 53         2020            6              2            24        2
# 54         2020            6              2            24        2
# 55         2020            6              2            24        2
#
#     time_in_seconds
# 0                67
# 1                74
# 2                88
# 3                30
# 4                64
# 5                48
# 6                59
# 7               121
# 8                33
# 9                70
# 10               21
# 11               35
# 12              127
# 13               87
# 14              103
# 15               54
# 16               66
# 17               20
# 18               58
# 19               76
# 20               14
# 21               30
# 22               51
# 23               12
# 24               58
# 25                7
# 26               39
# 27               25
# 28               44
# 29               62
# 30               24
# 31               32
# 32               48
# 33               66
# 34               83
# 35               26
# 36               52
# 37               34
# 38               48
# 39               68
# 40               61
# 41               56
# 42               40
# 43               24
# 44               82
# 45               17
# 46              126
# 47              100
# 48               89
# 49               15
# 50               18
# 51               42
# 52               85
# 53               97
# 54               64
# 55               56
